# %% [markdown]
# # <span style="color:#ffa500">Week 6 Assignment</span>

# %% [markdown]
# #### 1. Use Python to calculate solutions to the following expressions.

# %%
3*8
# Out:
# 24

# %%
(33+7)//5
# Out:
# 8

# %% [markdown]
# #### 2. Determine the data type of the output of the code `1+2.` and `1+2`. Explain why the data types are different.

# %%
# This expression involves an interger (1) and a float (2.0)
# Since one of the operands is a float, Python displays the result as a float
type(1+2.)
# Out:
# float

# %%
# This expression involves two intergers (1) and (2)
# Since both operands are intergers, Python displays the result as an int
type(1+2)
# Out:
# int

# %% [markdown]
# #### 3. Generate a loop that prints $n^{2}$ for each of the numbers $n = \{ 1,2,3,4,5 \}$.

# %%
for n in range(1,6):
    print(f"{n}^2 = {n**2}")
# Out:
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# 5^2 = 25

# %% [markdown]
# #### 4. Create the variable `i` by assigning the value $1$ to it. Create a loop that prints the value of $i^{2}$ to the screen. Increment the value of `i` by $1$ until the value of $i^{2}$ exceeds $1000$. Print the value assigned to `i` after the loop has completed. Explain why the solution is `i=32`, where $32^{2}$ is larger than $1000$.

# %%
# The result when i=31 is 961 which is lower than 1000
# Hence, the solution is i=32 because it is the first interger for which the result exceeds 1000
i = 1
while i**2 <= 1000:
    print(i**2)
    i += 1
print(f"The value of i after the loop is: {i}")
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# The value of i after the loop is: 32
