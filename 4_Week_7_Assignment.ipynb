# %% [markdown]
# # <span style="color:#ffa500">Week 7 Assignment</span>

# %% [markdown]
# ### <span style="color:#ffa500">Lists</span>

# %% [markdown]
# ##### 1. How do you define a list in Python?

# %%
my_list = [1,2,3,4,5]
my_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ##### 2. How do you access the third element of a Python list named my_list?

# %%
my_list = [1,2,3,4,5]
my_list[2]
# Out:
# 3

# %% [markdown]
# ##### 3. How can you add the element "new_item" to the end of an existing list named my_list?

# %%
my_list = [1,2,3,4,5]
my_list.append("new_item")
my_list
# Out:
# [1, 2, 3, 4, 5, 'new_item']

# %% [markdown]
# ### <span style="color:#ffa500">Tuples</span>

# %% [markdown]
# ##### 4. How do you create a Python tuple with the items "apple", "banana", and "cherry"?

# %%
my_tuple = "apple", "banana", "cherry"
my_tuple
# Out:
# ('apple', 'banana', 'cherry')

# %% [markdown]
# ##### 5. How do you access the first element of a Python tuple named my_tuple?

# %%
my_tuple = "apple", "banana", "cherry"
my_tuple[0]
# Out:
# 'apple'

# %% [markdown]
# ### <span style="color:#ffa500">Dictionaries</span>

# %% [markdown]
# ##### 6. How do you define a dictionary in Python with the keys "name", "age", and values "John Doe", 30?

# %%
my_dict = {"name":"John Doe", "age":30}
my_dict
# Out:
# {'name': 'John Doe', 'age': 30}

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_dict.values()
# Out:
# dict_values(['John Doe', 30])

# %% [markdown]
# ##### 7. How can you retrieve the value for the key "name" from the dictionary my_dict?

# %%
my_dict["name"]
# Out:
# 'John Doe'

# %% [markdown]
# ##### 8. How can you change the value associated with the key "age" in the dictionary my_dict to 35?

# %%
my_dict["age"] =35
my_dict["age"]
# Out:
# 35

# %% [markdown]
# ##### 9. How can you add a new key-vaue pair "city":"New York" to the dictionary my_dict?

# %%
my_dict["city"] = "New York"
my_dict
# Out:
# {'name': 'John Doe', 'age': 35, 'city': 'New York'}

# %% [markdown]
# ### <span style="color:#ffa500">Sets</span>

# %% [markdown]
# ##### 10. How do you create a set in Python with the items "apple", "banana", and "cherry"?

# %%
my_set = {"apple", "banana", "cherry"}
my_set
# Out:
# {'apple', 'banana', 'cherry'}

# %%
my_set = set(["apple", "banana", "cherry"])
my_set
# Out:
# {'apple', 'banana', 'cherry'}

# %% [markdown]
# ##### 11. How do you add the item "orange" to an existing set my_set?

# %%
my_set.add("orange")
my_set
# Out:
# {'apple', 'banana', 'cherry', 'orange'}

# %% [markdown]
# ##### 12. How do you remove the item "banana" from the set my_set?

# %%
my_set.remove("banana")
my_set
# Out:
# {'apple', 'cherry', 'orange'}

# %% [markdown]
# ### <span style="color:#ffa500">Lists</span>

# %% [markdown]
# ##### 13. What is the length of a list my_list with elements [1,2,3,4,5]?

# %%
my_list = [1,2,3,4,5]
len(my_list)
# Out:
# 5

# %% [markdown]
# ##### 14. What will the result of my_list*2 if my_list is [1,2,3]?

# %%
my_list = [1,2,3]
my_list*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %% [markdown]
# ### <span style="color:#ffa500">Sets</span>

# %% [markdown]
# ##### 15. What is the result of `set([1,2,2,3,4,4,4,5,5])`?

# %%
my_set = set([1,2,2,3,4,4,4,5,5])
my_set
# Out:
# {1, 2, 3, 4, 5}
